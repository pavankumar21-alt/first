# %%
import pandas as  pd

# %%
df=pd.read_csv("Global Electricity Statistics.csv")

df
# Out:
#                                Country              Features  \
# 0                              Algeria        net generation
# 1                               Angola        net generation
# 2                                Benin        net generation
# 3                             Botswana        net generation
# 4                         Burkina Faso        net generation
# ...                                ...                   ...
# 1605               Trinidad and Tobago  distribution losses
# 1606          Turks and Caicos Islands  distribution losses
# 1607               U.S. Virgin Islands  distribution losses
# 1608                           Uruguay  distribution losses
# 1609                         Venezuela  distribution losses
#
#                        Region     1980     1981     1982     1983     1984  \
# 0                      Africa    6.683     7.65    8.824    9.615   10.537
# 1                      Africa    0.905    0.906    0.995    1.028    1.028
# ...

# %%
df.drop([i for i in range(0,1500)],axis=0,inplace=True)
df.drop(['1981', '1982', '1983', '1984',
       '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
       '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
       '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
       '2012', '2013', '2014', '2015'],axis=1,inplace=True)

# %%
df=df.reset_index(drop=True)
df.head(50)
# Out:
#                              Country              Features          Region  \
# 0                             Brunei  distribution losses   Asia & Oceania
# 1                              Burma  distribution losses   Asia & Oceania
# 2                           Cambodia  distribution losses   Asia & Oceania
# 3                              China  distribution losses   Asia & Oceania
# 4                       Cook Islands  distribution losses   Asia & Oceania
# 5                               Fiji  distribution losses   Asia & Oceania
# 6                   French Polynesia  distribution losses   Asia & Oceania
# 7                               Guam  distribution losses   Asia & Oceania
# 8                Hawaiian Trade Zone  distribution losses   Asia & Oceania
# 9                          Hong Kong  distribution losses   Asia & Oceania
# 10                             India  distribution losses   Asia & Oceania
# ...

# %%
def imputation_inte(da_df,li_co_):
    for i in li_co_:
        da_df[i]=pd.to_numeric(da_df[i],errors='coerce')
        da_df[i] = da_df[i].fillna(0)
        da_df[i] = da_df[i].astype('int64')
        
imputation_inte(df,['1980', '2016', '2017', '2018', '2019',
       '2020', '2021'])

# %%
df.head(50)
# Out:
#                              Country              Features          Region  \
# 0                             Brunei  distribution losses   Asia & Oceania
# 1                              Burma  distribution losses   Asia & Oceania
# 2                           Cambodia  distribution losses   Asia & Oceania
# 3                              China  distribution losses   Asia & Oceania
# 4                       Cook Islands  distribution losses   Asia & Oceania
# 5                               Fiji  distribution losses   Asia & Oceania
# 6                   French Polynesia  distribution losses   Asia & Oceania
# 7                               Guam  distribution losses   Asia & Oceania
# 8                Hawaiian Trade Zone  distribution losses   Asia & Oceania
# 9                          Hong Kong  distribution losses   Asia & Oceania
# 10                             India  distribution losses   Asia & Oceania
# ...

# %%
df.dtypes
# Out:
# Country     object
# Features    object
# Region      object
# 1980         int64
# 2016         int64
# 2017         int64
# 2018         int64
# 2019         int64
# 2020         int64
# 2021         int64
# dtype: object
